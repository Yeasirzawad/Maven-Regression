# %% [markdown]
# ## Regression Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Maven Analytics Courses and Projects\Regression Maven Analytics\1. Resources\DataScienceinPythonRegression-230823-154628\Course Materials\Data\insurance.csv")

# %%
df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# Exploring Target Variable - Charges

# %%
sns.histplot(df["charges"])
# Out:
# <Axes: xlabel='charges', ylabel='Count'>

# %%
sns.boxplot(x = df["charges"])
# Out:
# <Axes: xlabel='charges'>

# %%
sns.boxenplot(x = df["charges"])
# Out:
# <Axes: xlabel='charges'>

# %% [markdown]
# Exploring the Features

# %%
df["region"].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
sns.histplot(x = df["bmi"])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(x = df["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# Correlations

# %%
sns.heatmap(df.corr(numeric_only= True),annot= True, vmin= -1, vmax= 1, cmap= "coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Exploring the Target vs Feature Relationships

# %%
sns.scatterplot(df,y= "charges",x= "age",hue= "smoker")
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
df.groupby("smoker")["charges"].mean().plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %% [markdown]
# Exploring Features vs Features Relationships
